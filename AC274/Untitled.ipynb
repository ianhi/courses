# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i/10.0))  # update the data
    return line,


# Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line,

anim = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init,
                              interval=25, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
from sympy import *

# %%
from sympy.abc import a,b
from IPython.display import display
init_session()
a, b, c = symbols('a b c', integer=True)
# Out:
# IPython console for SymPy 1.0 (Python 3.6.1-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at http://docs.sympy.org/1.0/

# %%
T_small = Matrix([[c,b,0,a],[a,c,b,0],[0,a,c,b],[b,0,a,c]])

# %%
T_small.eignvals()

# %%
phi_0, phi_1, phi_2, phi_3, phi_4, phi_5 = symbols('phi_0, phi_1 phi_2 phi_3 phi_4, phi_5', integer=True)

vec = Matrix([phi_0,phi_1,phi_2,phi_3])
ans = Matrix([phi_0,a*phi_0+c*phi_1+b*phi_2,a*phi_1+c*phi_2+b*phi_3,phi_3])
display(vec)
display(ans)
# Out:
# ⎡φ₀⎤
# ⎢  ⎥
# ⎢φ₁⎥
# ⎢  ⎥
# ⎢φ₂⎥
# ⎢  ⎥
# ⎣φ₃⎦
# ⎡        φ₀        ⎤
# ⎢                  ⎥
# ⎢a⋅φ₀ + b⋅φ₂ + c⋅φ₁⎥
# ⎢                  ⎥
# ⎢a⋅φ₁ + b⋅φ₃ + c⋅φ₂⎥
# ⎢                  ⎥
# ⎣        φ₃        ⎦

# %%
ans*inv_quick(vec)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-ba5b222a48c5> in <module>()
# ----> 1 ans*inv_quick(vec)
#
# /home/ianhi/anaconda3/lib/python3.6/site-packages/sympy/solvers/solvers.py in inv_quick(M)
#    2458         return M.inv()
#    2459     n = M.rows
# -> 2460     d = det(M)
#    2461     if d is S.Zero:
#    2462         raise ValueError("Matrix det == 0; not invertible.")
#
# /home/ianhi/anaconda3/lib/python3.6/site-packages/sympy/solvers/solvers.py in <lambda>(_)
#    2452     if any(i.has(Symbol) for i in M):
#    2453         if all(i.has(Symbol) for i in M):
# -> 2454             det = lambda _: det_perm(_)
#    2455         else:
#    2456             det = lambda _: det_minor(_)
#
# /home/ianhi/anaconda3/lib/python3.6/site-packages/sympy/solvers/solvers.py in det_perm(M)
#    2399         idx = 0
#    2400         for j in perm:
# ...

# %%
solve(T*vec )
# Out:
# ---------------------------------------------------------------------------
# NonSquareMatrixError                      Traceback (most recent call last)
# <ipython-input-53-fdcc2e0c8060> in <module>()
# ----> 1 vec.inv()
#
# /home/ianhi/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in inv(self, method, **kwargs)
#     308     def inv(self, method=None, **kwargs):
#     309         if not self.is_square:
# --> 310             raise NonSquareMatrixError()
#     311         if method is not None:
#     312             kwargs['method'] = method
#
# NonSquareMatrixError:

# %%
np.log()
