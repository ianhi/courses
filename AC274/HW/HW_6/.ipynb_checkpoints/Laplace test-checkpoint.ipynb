# %%
# %matplotlib inline
from python_muphase_no_hist import *
import matplotlib as mpl
mpl.style.use(['fivethirtyeight', 'figsize'])
fs = 15
_SAVEDIR_ = 'Tex/figures/'

# %% [markdown]
# ## Laplace test varying radius for a given G

# %%
out_19 = run(G=-4.9, Nsteps=100, radius_init=19)
# Out:
# G: -4.9
# Radius: 5.0
# Radius2: 21.45143178679422
# Delta P: 0.04451846301273306
# Pmin: 0.0009711136386963415
# Pmax: 0.0454895766514294

# %%
rad_list = [15,16,17,18,19,20,20.5,21,21.5,22,23,24,25]
G = -4.9
out_list = []
Nsteps = 15000
for R in rad_list:
    out_list.append(run(G=G, Nsteps=Nsteps, radius_init=R))
# Out:
# G: -4.9
# Radius: 12.0
# Radius2: 11.15028764700742
# Delta P: 0.04454065419016104
# Pmin: 0.0009295989292981699
# Pmax: 0.04547025311945921
# G: -4.9
# Radius: 13.0
# Radius2: 12.80001446722779
# Delta P: 0.04456756908648424
# Pmin: 0.0009218661067803002
# Pmax: 0.04548943519326454
# G: -4.9
# Radius: 15.0
# Radius2: 14.233009791900212
# Delta P: 0.044563179593230334
# Pmin: 0.0009211001044283629
# Pmax: 0.0454842796976587
# G: -4.9
# Radius: 17.0
# Radius2: 15.77114648483078
# Delta P: 0.04456454094784014
# Pmin: 0.0009218251807950328
# Pmax: 0.04548636612863517
# G: -4.9
# Radius: 18.0
# Radius2: 17.211885663100027
# Delta P: 0.044434881632649637
# Pmin: 0.00105129285193295
# Pmax: 0.04548617448458259
# G: -4.9
# Radius: 19.0
# Radius2: 18.538308064711035
# Delta P: 0.04456887523979379
# Pmin: 0.0009211898643821659
# Pmax: 0.045490065104175956
# G: -4.9
# Radius: 20.0
# Radius2: 19.247856593441615
# Delta P: 0.04454560389757389
# Pmin: 0.0009247045941609966
# Pmax: 0.04547030849173489
# G: -4.9
# Radius: 21.0
# Radius2: 19.813670378608983
# Delta P: 0.04454368902053317
# Pmin: 0.0009470560230968594
# Pmax: 0.04549074504363003
# G: -4.9
# Radius: 22.0
# Radius2: 20.666767363759902
# Delta P: 0.0445324061472058
# Pmin: 0.0009581222450543714
# Pmax: 0.04549052839226017
# G: -4.9
# Radius: 22.0
# Radius2: 21.191080589136487
# Delta P: 0.044522840957618215
# Pmin: 0.0009677771367959109
# Pmax: 0.045490618094414126
# G: -4.9
# Radius: 24.0
# Radius2: 22.420739609518552
# Delta P: 0.04455021626428335
# Pmin: 0.000921218622443265
# Pmax: 0.045471434886726614
# G: -4.9
# Radius: 25.0
# Radius2: 23.607543706839163
# Delta P: 0.04455360902001797
# Pmin: 0.0009367467536911533
# Pmax: 0.04549035577370912
# G: -4.9
# Radius: 26.0
# Radius2: 24.838016705629713
# Delta P: 0.044559647480297684
# Pmin: 0.0009307483804010253
# Pmax: 0.04549039586069871

# %%
#out_19 = run(G=-4.9, Nsteps=15000, radius_init=19)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ddc829d7c376> in <module>()
# ----> 1 out_19 = run(G=-4.9, Nsteps=15000, radius_init=19)
#
# NameError: name 'run' is not defined

# %%
rho = out_19['rho']
psi = 1-np.exp(-rho)
press = rho*cs2+.5*-4.9*cs2*psi**2
# plt.imshow(rho)
# plt.colorbar()
print(np.min(rho))
lx=128
print(press[int(lx/16),int(lx/16)])
print(np.min(press))
print()
print(press[int(lx/2),int(lx/2)])
print(np.max(press))
print()
print(np.average(rho))

plt.imshow(press)
plt.colorbar()
# Out:
# 0.174506654717
# 0.0372407285878
# 0.00107713699579
#
# 0.0399277560667
# 0.0454853682719
#
# 0.281231301772

# %%
invradii = []
dP = []
for out in out_list:
    invradii.append(1./out['radius2'])
    dP.append(out['deltaP2'])
plt.plot(invradii,dP,'o')
for i, txt in enumerate(rad_list):
    plt.annotate(txt, (invradii[i],dP[i]),fontsize = fs)
plt.xlabel(r'$\frac{1}{R}$',fontsize=25)
plt.ylabel('Delta P')
# plt.xlim([1/21,.06])
# plt.plot([1/21.09],[.09],'ro')
plt.show()

# %% [markdown]
# # ok finally a linear thing!!
# now lets do it for multiple G

# %%
rad_list2 = [15,16,17,18,21,25]
g_list = [-4.7,-4.8,-4.9,-5,-5.1]
out_list = []
Nsteps = 10000
for g, G in enumerate(g_list):
    out_list.append([])
    for R in rad_list2:
        out_list[g].append(run(G=G,Nsteps = Nsteps, radius_init=R))

# for R in rad_list:
#     out_list.append(run(G=G, Nsteps=Nsteps, radius_init=R))
# Out:
# G: -4.7
# Radius: 46.0
# Radius2: 1.176775850902548
# Delta P: 9.005536752114407e-06
# Pmin: 0.04292742462236715
# Pmax: 0.042936430159119264
# G: -4.7
# Radius: 58.0
# Radius2: 0.5004032741738575
# Delta P: 1.718910635557791e-06
# Pmin: 0.04398264950566412
# Pmax: 0.04398436841629968
# G: -4.7
# Radius: 11.0
# Radius2: 10.358449358777102
# Delta P: 0.030972346642339152
# Pmin: 0.017441030597775298
# Pmax: 0.04841337724011445
# G: -4.7
# Radius: 13.0
# Radius2: 12.684323894169465
# Delta P: 0.03097212404826688
# Pmin: 0.017440887221677026
# Pmax: 0.048413011269943906
# G: -4.7
# Radius: 19.0
# Radius2: 17.945457226189664
# Delta P: 0.030924844973774415
# Pmin: 0.01748853166326514
# Pmax: 0.048413376637039554
# G: -4.7
# Radius: 26.0
# Radius2: 23.88631724028996
# Delta P: 0.030964143985619003
# Pmin: 0.01744565623024036
# Pmax: 0.04840980021585936
# G: -4.8
# Radius: 9.0
# Radius2: 8.730992418984346
# Delta P: 0.03756151240770535
# Pmin: 0.00933787939011832
# Pmax: 0.04689939179782367
# G: -4.8
# Radius: 12.0
# Radius2: 10.967239352341425
# Delta P: 0.037579193584889495
# Pmin: 0.00932031314190096
# Pmax: 0.046899506726790455
# G: -4.8
# Radius: 13.0
# Radius2: 12.721490480307802
# Delta P: 0.037536713843332056
# Pmin: 0.009337795058602938
# Pmax: 0.046874508901934994
# G: -4.8
# Radius: 15.0
# Radius2: 14.527365804770817
# Delta P: 0.037577167341636575
# Pmin: 0.009322347414153442
# Pmax: 0.04689951475579002
# G: -4.8
# Radius: 20.0
# Radius2: 19.04085991345297
# Delta P: 0.03757469852204692
# Pmin: 0.009307998746115764
# Pmax: 0.04688269726816269
# G: -4.8
# Radius: 26.0
# Radius2: 24.455811949379058
# Delta P: 0.03753202740598775
# Pmin: 0.0093660657061298
# Pmax: 0.04689809311211755
# G: -4.9
# Radius: 12.0
# Radius2: 11.154925649796901
# Delta P: 0.04453642760943137
# Pmin: 0.0009322399699147055
# Pmax: 0.045468667579346075
# G: -4.9
# Radius: 13.0
# Radius2: 12.79929512134608
# Delta P: 0.04456715597653424
# Pmin: 0.0009223088506351562
# Pmax: 0.045489464827169396
# G: -4.9
# Radius: 15.0
# Radius2: 14.229153698227272
# Delta P: 0.044562293665548716
# Pmin: 0.0009212491186901262
# Pmax: 0.04548354278423884
# G: -4.9
# Radius: 17.0
# Radius2: 15.77020725707423
# Delta P: 0.04456401290262846
# Pmin: 0.0009224403831630257
# Pmax: 0.045486453285791484
# G: -4.9
# Radius: 21.0
# Radius2: 19.81421320867964
# Delta P: 0.04454339092203262
# Pmin: 0.0009473545503454472
# Pmax: 0.045490745472378066
# G: -4.9
# Radius: 26.0
# Radius2: 24.835799095309216
# Delta P: 0.044560616512276066
# Pmin: 0.0009299048818973699
# Pmax: 0.045490521394173436
# G: -5
# Radius: 13.0
# Radius2: 12.646907401649427
# Delta P: 0.051868838292701946
# Pmin: -0.007694747363946652
# Pmax: 0.044174090928755294
# G: -5
# Radius: 15.0
# Radius2: 14.032898048028214
# Delta P: 0.05184263195484633
# Pmin: -0.007675542969840521
# Pmax: 0.044167088985005806
# G: -5
# Radius: 16.0
# Radius2: 15.27877576466525
# Delta P: 0.05186425134405473
# Pmin: -0.00769472225416018
# Pmax: 0.04416952908989455
# G: -5
# Radius: 17.0
# Radius2: 16.659509181501182
# Delta P: 0.05185481940172729
# Pmin: -0.007695386139033589
# Pmax: 0.0441594332626937
# G: -5
# Radius: 21.0
# Radius2: 20.36815729544952
# Delta P: 0.051856245224035744
# Pmin: -0.007681537199739408
# Pmax: 0.044174708024296336
# G: -5
# Radius: 26.0
# Radius2: 25.087895495487913
# Delta P: 0.05166894291427517
# Pmin: -0.007504499159872391
# Pmax: 0.04416444375440278
# G: -5.1
# Radius: 14.0
# Radius2: 13.687535294611179
# Delta P: 0.0590192030857889
# Pmin: -0.016079971650006075
# Pmax: 0.04293923143578283
# G: -5.1
# Radius: 15.0
# Radius2: 14.91959777243153
# Delta P: 0.05946730601234779
# Pmin: -0.0165276989080278
# Pmax: 0.04293960710431999
# G: -5.1
# Radius: 17.0
# Radius2: 16.04788602816641
# Delta P: 0.05942034472796
# Pmin: -0.016509707214688474
# Pmax: 0.042910637513271524
# G: -5.1
# Radius: 18.0
# Radius2: 17.31060608237517
# Delta P: 0.059273183289629265
# Pmin: -0.016378077846044115
# Pmax: 0.04289510544358515
# G: -5.1
# Radius: 22.0
# Radius2: 20.76778467659723
# Delta P: 0.059462982182101706
# Pmin: -0.016527028417392675
# Pmax: 0.04293595376470903
# G: -5.1
# Radius: 26.0
# Radius2: 25.246683289669743
# Delta P: 0.05942503541956666
# Pmin: -0.01650283107045092
# Pmax: 0.04292220434911574

# %%
import pickle
with open('laplace_test_data_good', "wb") as fp:
    pickle.dump(out_list, fp)
with open('laplace_test_data_good', "rb") as fp:
    out_list_new = pickle.load(fp)
for g_out in out_list_new[1:]:
    invradii = []
    dP = []
    for o in g_out:
        invradii.append(1./o['radius2'])
        dP.append(o['deltaP2'])
    plt.plot(invradii,dP,'o-',label='G = {:}'.format(o['G']),ms=15)
plt.xlabel(r'$\frac{1}{R}$',fontsize=25)
plt.ylabel(r'$\Delta P$')
plt.legend()
plt.savefig(_SAVEDIR_+"Laplace_test_multG.png")

# %%
for g_out in out_list[1:]:
    o = g_out[0]
    o2 = g_out[1]
    rads = o['radius2']
    dPs = o['deltaP2']
    print((o['deltaP2']-o2['deltaP2'])/(1/o['radius2']-1/o2['radius2']))
    print(1/o['G'])
    print()
# Out:
# 0.0373269267396
# -0.20833333333333334
#
# 0.0449124808507
# -0.2040816326530612
#
# 0.0523443062932
# -0.2
#
# 0.059955253436
# -0.19607843137254904

# %%
for g_out in out_list[1:]:
    invradii = []
    dP = []
    for o in g_out:
        invradii.append(1./o['radius2'])
        dP.append(o['deltaP2'])
    plt.plot(invradii,dP,'o',label='G = {:}'.format(o['G']))
plt.legend()

# %%
ls
# Out:
# BGK_2.forces_1D            muphase_-4.9_11000_21.npy
# BGK_2.rho_u_v_1D           muphase_-4.9_11000_25.npy
# BGK_2.ruv2d                muphase_-4.9_15000_15.npy
# dump_pop                   muphase_-4.9_15000_16.npy
# dump_rhod1                 muphase_-4.9_15000_17.npy
# dump_u1_v1                 muphase_-4.9_15000_18.npy
# execute_fast.sh*           muphase_-4.9_15000_19.npy
# execute.sh*                muphase_-4.9_15000_20.5.npy
# gnuplot_2D_fields.gnu      muphase_-4.9_15000_20.npy
# laplace_test_data          muphase_-4.9_15000_21.5.npy
# Laplace test.ipynb         muphase_-4.9_15000_21.npy
# movie_2D.bgk               muphase_-4.9_15000_22.npy
# Multiphase d2q9.ipynb      muphase_-4.9_15000_23.npy
# muphase*                   muphase_-4.9_15000_24.npy
# muphase_-4.7_10000_15.npy  muphase_-4.9_15000_25.npy
# muphase_-4.7_10000_16.npy  muphase_-5_10000_15.npy
# muphase_-4.7_10000_17.npy  muphase_-5_10000_16.npy
# muphase_-4.7_10000_18.npy  muphase_-5_10000_17.npy
# muphase_-4.7_10000_21.npy  muphase_-5_10000_18.npy
# muphase_-4.7_10000_25.npy  muphase_-5_10000_21.npy
# muphase_-4.7_100_15.npy    muphase_-5_10000_25.npy
# muphase_-4.7_100_16.npy    muphase_-5_100_15.npy
# muphase_-4.7_100_17.npy    muphase_-5_100_16.npy
# muphase_-4.7_100_18.npy    muphase_-5_100_17.npy
# muphase_-4.7_100_19.npy    muphase_-5_100_18.npy
# muphase_-4.7_100_21.npy    muphase_-5_100_19.npy
# muphase_-4.7_100_25.npy    muphase_-5_100_21.npy
# muphase_-4.7_10_15.npy     muphase_-5_100_25.npy
# muphase_-4.7_10_16.npy     muphase_-5_10_15.npy
# muphase_-4.7_10_17.npy     muphase_-5_10_16.npy
# muphase_-4.7_10_18.npy     muphase_-5_10_17.npy
# muphase_-4.7_10_21.npy     muphase_-5_10_18.npy
# muphase_-4.7_10_25.npy     muphase_-5_10_21.npy
# muphase_-4.7_11000_15.npy  muphase_-5_10_25.npy
# muphase_-4.7_11000_16.npy  muphase_-5.1_10000_15.npy
# muphase_-4.7_11000_17.npy  muphase_-5.1_10000_16.npy
# muphase_-4.7_11000_18.npy  muphase_-5.1_10000_17.npy
# muphase_-4.7_11000_19.npy  muphase_-5.1_10000_18.npy
# muphase_-4.7_11000_21.npy  muphase_-5.1_10000_21.npy
# muphase_-4.7_11000_25.npy  muphase_-5.1_10000_25.npy
# muphase_-4.8_10000_15.npy  muphase_-5_11000_15.npy
# muphase_-4.8_10000_16.npy  muphase_-5_11000_16.npy
# muphase_-4.8_10000_17.npy  muphase_-5_11000_17.npy
# muphase_-4.8_10000_18.npy  muphase_-5_11000_18.npy
# muphase_-4.8_10000_21.npy  muphase_-5_11000_19.npy
# muphase_-4.8_10000_25.npy  muphase_-5_11000_21.npy
# muphase_-4.8_100_15.npy    muphase_-5_11000_25.npy
# muphase_-4.8_100_16.npy    muphase_-5.1_100_15.npy
# muphase_-4.8_100_17.npy    muphase_-5.1_100_16.npy
# muphase_-4.8_100_18.npy    muphase_-5.1_100_17.npy
# muphase_-4.8_100_19.npy    muphase_-5.1_100_18.npy
# muphase_-4.8_100_21.npy    muphase_-5.1_100_19.npy
# muphase_-4.8_100_25.npy    muphase_-5.1_100_21.npy
# muphase_-4.8_10_15.npy     muphase_-5.1_100_25.npy
# muphase_-4.8_10_16.npy     muphase_-5.1_10_15.npy
# muphase_-4.8_10_17.npy     muphase_-5.1_10_16.npy
# muphase_-4.8_10_18.npy     muphase_-5.1_10_17.npy
# muphase_-4.8_10_21.npy     muphase_-5.1_10_18.npy
# muphase_-4.8_10_25.npy     muphase_-5.1_10_21.npy
# muphase_-4.8_11000_15.npy  muphase_-5.1_10_25.npy
# muphase_-4.8_11000_16.npy  muphase_-5.1_11000_15.npy
# muphase_-4.8_11000_17.npy  muphase_-5.1_11000_16.npy
# muphase_-4.8_11000_18.npy  muphase_-5.1_11000_17.npy
# muphase_-4.8_11000_19.npy  muphase_-5.1_11000_18.npy
# muphase_-4.8_11000_21.npy  muphase_-5.1_11000_19.npy
# muphase_-4.8_11000_25.npy  muphase_-5.1_11000_21.npy
# muphase_-4.9_10000_15.npy  muphase_-5.1_11000_25.npy
# muphase_-4.9_10000_16.npy  muphase_-5.2_100_15.npy
# muphase_-4.9_10000_17.npy  muphase_-5.2_100_16.npy
# muphase_-4.9_10000_18.npy  muphase_-5.2_100_17.npy
# muphase_-4.9_10000_20.npy  muphase_-5.2_100_18.npy
# muphase_-4.9_10000_21.npy  muphase_-5.2_100_19.npy
# muphase_-4.9_10000_22.npy  muphase_-5.2_100_21.npy
# muphase_-4.9_10000_25.npy  muphase_-5.2_100_25.npy
# muphase_-4.9_1000_15.npy   muphase_-5.2_11000_15.npy
# muphase_-4.9_1000_20.npy   muphase_-5.2_11000_16.npy
# muphase_-4.9_1000_21.npy   muphase_-5.2_11000_17.npy
# muphase_-4.9_1000_22.npy   muphase_-5.2_11000_18.npy
# muphase_-4.9_1000_25.npy   muphase_-5.2_11000_19.npy
# muphase_-4.9_100_15.npy    muphase_-5.2_11000_21.npy
# muphase_-4.9_100_16.npy    muphase_-5.2_11000_25.npy
# muphase_-4.9_100_17.npy    muphase_Falcucci.f
# muphase_-4.9_100_18.npy    muphase_Falcucci_fast.f
# muphase_-4.9_100_19.npy    muphase_fast*
# muphase_-4.9_100_21.npy    muphase.inp
# muphase_-4.9_100_25.npy    muphase.par
# muphase_-4.9_10_15.npy     out_mov.mp4
# muphase_-4.9_10_16.npy     poiseuille flow with obstacle.ipynb
# muphase_-4.9_10_17.npy     press_field.dat
# muphase_-4.9_10_18.npy     __pycache__/
# muphase_-4.9_10_21.npy     python_muphase_no_hist.py
# muphase_-4.9_10_25.npy     python_muphase.py
# muphase_-4.9_11000_15.npy  run_fortran/
# muphase_-4.9_11000_16.npy  Tex/
# muphase_-4.9_11000_17.npy  Untitled1.ipynb
# muphase_-4.9_11000_18.npy  Untitled.ipynb
# muphase_-4.9_11000_19.npy

# %%
invradii = []
dP = []
for out in out_list[:]:
    invradii.append(1./out['radius2'])
    dP.append(out['deltaP2'])
plt.plot(invradii,dP,'o')
for i, txt in enumerate(rad_list):
    plt.annotate(txt, (invradii[i],dP[i]),fontsize = fs)
plt.xlabel(r'$\frac{1}{R}$',fontsize=25)
plt.ylabel('Delta P')
# plt.xlim([1/21,.06])
# plt.plot([1/21.09],[.09],'ro')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-68ce6f2abccd> in <module>()
#       2 dP = []
#       3 for out in out_list[:]:
# ----> 4     invradii.append(1./out['radius2'])
#       5     dP.append(out['deltaP2'])
#       6 plt.plot(invradii,dP,'o')
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ## Old stuff where I varied G rather than initial radius

# %%
g_list = [-4.7,-4.8,-4.9,-5,-5.1,-5.2,-5.3,-5.4,-5.5]
out_list = []
Nsteps = 10000
for g in g_list:
    out_list.append(run(G=g,Nsteps= Nsteps))
# Out:
# G: -4.7
# Radius: 17.0
# Delta P: 0.030874801982227293
# Pmin: 0.017538544367934394
# Pmax: 0.04841334635016169
# G: -4.8
# Radius: 19.0
# Delta P: 0.037578055583748105
# Pmin: 0.009321429426414174
# Pmax: 0.04689948501016228
# G: -4.9
# Radius: 19.0
# Delta P: 0.044568086402887966
# Pmin: 0.0009221065093672487
# Pmax: 0.045490192912255215
# G: -5
# Radius: 20.0
# Delta P: 0.051844717167763704
# Pmin: -0.007685298490533177
# Pmax: 0.04415941867723053
# G: -5.1
# Radius: 20.0
# Delta P: 0.059457565118846686
# Pmin: -0.01651662789697067
# Pmax: 0.042940937221876016
# G: -5.2
# Radius: 21.0
# Delta P: 0.0672956416147769
# Pmin: -0.02553194905956946
# Pmax: 0.04176369255520744
# G: -5.3
# Radius: 21.0
# Delta P: 0.07546707317392375
# Pmin: -0.034778092843135544
# Pmax: 0.0406889803307882
# G: -5.4
# Radius: 21.0
# Delta P: 0.08380131322281362
# Pmin: -0.04414485542015861
# Pmax: 0.03965645780265501
# G: -5.5
# Radius: 21.0
# Delta P: 0.09218320592016253
# Pmin: -0.05350347730756394
# Pmax: 0.03867972861259859

# %%
invradii = []
dP = []
for out in out_list:
    invradii.append(1./out['radius'])
    dP.append(out['pmax']-out['pmin'])

plt.plot(invradii,dP,'o')
# plt.xlim([1/21,.06])
plt.plot([1/21.09],[.09],'ro')
plt.show()

# %%
lx = 128
ly = 128
def calc_radius(rho,lx=128,ly=128):
    rho_cent = rho[int(lx/2),int(ly/2)]
#     rho_out = rho[int(lx/16),int(ly/16)]
    
    rho_out = np.min(rho)
    mass_cent = np.average(rho)*lx*ly - rho_out*lx*ly
    rho_cent = rho_cent-rho_out
    return (mass_cent/(rho_cent*np.pi))**.5
calc_radius(calc_macro_f(out_list[3]['f'],lx,ly)[0])
# Out:
# 20.032581311530297

# %%
invradii = []
dP = []
for out in out_list:
    invradii.append(1./calc_radius(calc_macro_f(out['f'],lx,ly)[0]))
    dP.append(out['pmax']-out['pmin'])
plt.plot(invradii,dP,'o')
for i, txt in enumerate(g_list):
    plt.annotate(txt, (invradii[i],dP[i]),fontsize = fs)

plt.xlabel(r'$\frac{1}{R}$',fontsize=fs*2)
plt.ylabel(r'$\Delta P$',fontsize=fs)
plt.tight_layout()
plt.savefig(_SAVEDIR_+'laplace_radInit21.png')

# %%
x = np.linspace(.1,1,100)
plt.plot(x,np.log(1/x))

# %%
invradii = []
dP = []
for out in out_list:
    invradii.append(1./calc_radius(calc_macro_f(out['f'],lx,ly)[0]))
    dP.append(np.log(out['pmax']-out['pmin']))
plt.plot(invradii,dP,'o')
for i, txt in enumerate(g_list):
    plt.annotate(txt, (invradii[i],dP[i]),fontsize = fs)

plt.xlabel(r'$\frac{1}{R}$',fontsize=fs*2)
plt.ylabel(r'$\Delta P$',fontsize=fs)
plt.savefig(_SAVEDIR_+'laplace_radInit21.png')

# %%
for out in out_list:
    print(str(np.abs(out['G']))+' & '+str(calc_radius(calc_macro_f(out['f'],lx,ly)[0]))+'\\ \hline')
# Out:
# 4.7 & 17.4617962346\ \hline
# 4.8 & 18.6576139421\ \hline
# 4.9 & 19.4669714085\ \hline
# 5 & 20.0325813115\ \hline
# 5.1 & 20.4114063816\ \hline
# 5.2 & 20.6869834886\ \hline
# 5.3 & 20.8710914618\ \hline
# 5.4 & 20.9812428476\ \hline
# 5.5 & 21.061187326\ \hline

# %%
g_list = [-4.7,-4.8,-4.9,-5,-5.1,-5.2,-5.3,-5.4,-5.5]
out_list2 = []
Nsteps = 10000
for g in g_list:
    out_list2.append(run(G=g,Nsteps= Nsteps,radius_init=24))
# Out:
# G: -4.7
# Radius: 24.0
# Delta P: 0.03093802548418695
# Pmin: 0.017442268849149067
# Pmax: 0.048380294333336016
# G: -4.8
# Radius: 25.0
# Delta P: 0.037593228168928516
# Pmin: 0.00930579147079369
# Pmax: 0.046899019639722206
# G: -4.9
# Radius: 25.0
# Delta P: 0.04455472815726409
# Pmin: 0.0009357074442032376
# Pmax: 0.04549043560146733
# G: -5
# Radius: 25.0
# Delta P: 0.05173360068738375
# Pmin: -0.007570389743780104
# Pmax: 0.04416321094360365
# G: -5.1
# Radius: 25.0
# Delta P: 0.05944581500735849
# Pmin: -0.016505718718780094
# Pmax: 0.042940096288578394
# G: -5.2
# Radius: 25.0
# Delta P: 0.06734375783202942
# Pmin: -0.02556217620445589
# Pmax: 0.041781581627573526
# G: -5.3
# Radius: 25.0
# Delta P: 0.07544258074130203
# Pmin: -0.03476867704195946
# Pmax: 0.040673903699342574
# G: -5.4
# Radius: 25.0
# Delta P: 0.08382288577944712
# Pmin: -0.044190456657939414
# Pmax: 0.039632429121507703
# G: -5.5
# Radius: 25.0
# Delta P: 0.09242817584383535
# Pmin: -0.05374844810298052
# Pmax: 0.03867972774085483

# %%
invradii = []
dP = []
for out in out_list2:
    invradii.append(1./calc_radius(calc_macro_f(out['f'],lx,ly)[0]))
    dP.append(out['pmax']-out['pmin'])
plt.figure(figsize = (9,9))
plt.plot(invradii,dP,'o')
# plt.xlim([1/21,.06])
# plt.plot([1/21.09],[.09],'ro')

for i, txt in enumerate(g_list):
    plt.annotate(txt, (invradii[i],dP[i]),fontsize = fs)
plt.xlabel(r'$\frac{1}{R}$',fontsize = fs*2)
plt.ylabel(r'$\Delta P$',fontsize = fs)
plt.tight_layout()
plt.savefig(_SAVEDIR_+'laplace_radInit24.png')

# %%
rho = calc_macro_f(out_list[2]['f'],lx=128,ly=128)[0]
plt.imshow(flip_T(rho))
plt.colorbar()
plt.grid('off')
plt.show()

# %%
plt.plot((rho[:,int(128/2)]))

# %%
out = run(G=-4.7,Nsteps = 1000)
rho = calc_macro_f(out['f'],lx=128,ly=128)[0]
plt.imshow(flip_T(rho))
cbar = plt.colorbar()
cbar.ax.set_ylabel('Density')

plt.grid('off')
plt.tight_layout()
# plt.savefig(_SAVEDIR_+"muphase_G_46.png")
plt.show()
# Out:
# G: -4.7
# Radius: 17.0
# Delta P: 0.04712819324460121
# Pmin: 0.01744101900088585
# Pmax: 0.06456921224548706

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.animation as animation
import numexpr as ne
mpl.style.use(['fivethirtyeight', 'figsize'])


# define constants
lx =128
ly = lx
Nsteps = 2000
ex=[0,1,0,-1,0 ,1,-1,-1, 1]
ey=[0,0,1,0 ,-1,1, 1,-1,-1]
w = [4./9,1./9,1./9,1./9,1./9,1./36,1./36,1./36,1./36]
G = -4.5
omega = 1
rho_psi = 1

cs = 1/np.sqrt(3)
cs2  = 1.00 / 3.00
cs22 = 2.00 * cs2
cssq = 2.0 / 9.00
#plotting functions:
def flip_T(a):
    return np.flipud(a.T)
def calc_macro_f(f):
    #Assumes f at a given time step
    #  this fxn shouldn't be used in the loops as it takes times to create new numpy arrays
    # useful after running for getting macro quantities w/o having the rho,u, and v arrays handy
    u = np.zeros([lx,ly])
    v = np.zeros([lx,ly])

    rho = np.sum(f,axis=0)
    for k in range(9):
        u += f[k]*ex[k]
        v += f[k]*ey[k]
    u=u/rho
    v=v/rho
    return rho, u ,v

# simulation functions
def equilibrium(rho,u,v):
    feq = np.zeros([9,lx,ly])
    usq = u*u
    vsq = v*v
    sumsq = (usq+vsq)/cs22
    sumsq2 = sumsq*(1-cs2)/cs2
    u22 = usq/cssq
    v22 = vsq/cssq
    ui = u/cs2
    vi = v/cs2
    uv = ui*vi
    feq[0] = (4.0/9.0)*rho*(1.00 - sumsq)

    feq[1] = (1.0/9.0)*rho*(1.00 - sumsq + u22 + ui)
    feq[2] = (1.0/9.0)*rho*(1.00 - sumsq + v22 + vi)
    feq[3] = (1.0/9.0)*rho*(1.00 - sumsq + u22 - ui)
    feq[4] = (1.0/9.0)*rho*(1.00 - sumsq + v22 - vi)

    feq[5] = (1.0/36.0)*rho*(1.00 + sumsq2 + ui + vi + uv)
    feq[6] = (1.0/36.0)*rho*(1.00 + sumsq2 - ui + vi - uv)
    feq[7] = (1.0/36.0)*rho*(1.00 + sumsq2 - ui - vi + uv)
    feq[8] = (1.0/36.0)*rho*(1.00 + sumsq2 + ui - vi - uv)
    return feq
def calc_force(rho):
    psi = ne.evaluate('rho_psi*(1-exp(-rho/rho_psi))')
    # a negative roll velocity implied i+1

    f_x = psi*(np.roll(psi,(-1,0),(0,1))-np.roll(psi,(1,0),(0,1)))
    f_y = psi*(np.roll(psi,(0,-1),(0,1))-np.roll(psi,(0,1),(0,1)))

    f2_x = psi*(np.roll(psi,(-1,1),(0,1))+np.roll(psi,(-1,-1),(0,1))-np.roll(psi,(1,1),(0,1))-np.roll(psi,(1,-1),(0,1)))


    f2_y = psi*(np.roll(psi,(-1,-1),(0,1))+np.roll(psi,(1,-1),(0,1))
                -np.roll(psi,(1,1),(0,1))-np.roll(psi,(-1,1),(0,1)))

    force_x = -G*(f_x/9+f2_x/36)
    force_y = -G*(f_y/9+f2_y/36)
    return force_x, force_y
def fast(rho, Nsteps):
    f = np.zeros([Nsteps, 9,lx,ly])
    u = np.zeros([lx,ly])
    v = np.zeros([lx,ly])

    for kk in range(0,9):
        f[0,kk,:,:] = w[kk]*rho

    for ts in range(1,Nsteps):
        # if ts%100==0:
        #     print(ts)
#         prog_bar(ts,Nsteps)
        fout = np.copy(f[ts-1])
        for kk in range(0,9):
            f[ts,kk,:,:] = np.roll(fout[kk,:,:],(ex[kk],ey[kk]),(0,1))

        u[:,:] = 0
        v[:,:] = 0

        rho = np.sum(f[ts],axis=0)
        for k in range(9):
            u += f[ts,k]*ex[k]
            v += f[ts, k]*ey[k]
        u=u/rho
        v=v/rho


        force_x, force_y = calc_force(rho)
        u += force_x/(omega*rho)
        v += force_y/(omega*rho)

        #=======================================
        cs2  = 1.00 / 3.00
        cs22 = 2.00 * cs2
        cssq = 2.0 / 9.00
        feq = equilibrium(rho,u,v)
        for k in range(9):
            f[ts,k] = feq[k]
    return f
def init_rho():
    rho= np.zeros([lx,ly])
    disp_x = lx/2
    disp_y = ly/2
    y,x = np.ogrid[-disp_x:lx-disp_x,-disp_y:ly-disp_y]
    radius = 20
    mask = x*x +y*y < radius**2
    rho[mask] = 2.4
    rho *= 1+.05*(np.random.rand(lx,ly)-.5)
    rho[mask == 0] = .125
    return rho
def determine_radius(rho):
    rho_cent = rho[int(lx/2),int(ly/2)]
    rho_out = rho[int(lx/8),int(ly/8)]
    target = (rho_cent+rho_out)/2
    idx = np.argmin(np.abs(rho[:,int(ly/2)] - target))
    return np.abs(lx/2-idx)
def pressure(rho):
    psi = rho_psi*(1-np.exp(-rho/rho_psi))
    press = (rho*cs2+.5*G*cs2*psi**2)
    pmax = np.max(press)
    pmin = np.min(press)
    return pmin, pmax

rho_init = init_rho()
plt.imshow(flip_T(rho_init))
plt.colorbar()
plt.grid('off')
plt.show()


a = fast(rho_init, Nsteps)
rho = calc_macro_f(a)[0]
print("Radius: {:}".format(determine_radius(rho)))
print("Pressures:")
print(pressure(rho))
plt.imshow(flip_T(rho))
plt.colorbar()
plt.grid('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-5d426dee06ce> in <module>()
#     151
#     152 a = fast(rho_init, Nsteps)
# --> 153 rho = calc_macro_f(a)[0]
#     154 print("Radius: {:}".format(determine_radius(rho)))
#     155 print("Pressures:")
#
# <ipython-input-2-5d426dee06ce> in calc_macro_f(f)
#      34     rho = np.sum(f,axis=0)
#      35     for k in range(9):
# ---> 36         u += f[k]*ex[k]
#      37         v += f[k]*ey[k]
#      38     u=u/rho
#
# ValueError: non-broadcastable output operand with shape (128,128) doesn't match the broadcast shape (9,128,128)

# %%
rho_init = init_rho()
plt.imshow(flip_T(rho_init))
cbar = plt.colorbar()
cbar.ax.set_ylabel('Density')
plt.grid('off')
plt.savefig(_SAVEDIR_+'laplace_init.png')

# %%
rho = calc_macro_f(a[0])[0]
print("Radius: {:}".format(determine_radius(rho)))
print("Pressures:")
print(pressure(rho))
plt.imshow(flip_T(rho))
plt.colorbar()
plt.grid('off')
plt.show()
# Out:
# Radius: 13.0
# Pressures:
# (0.031311433240006112, 0.1926297094351912)
